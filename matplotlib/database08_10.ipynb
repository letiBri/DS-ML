# %%
import pandas as pd

# %%
df=pd.read_csv("AmesHousing.csv")

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2      NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3      NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4      NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2925   NaN       IR1          Lvl  ...         0     NaN  GdPrv          NaN
# 2926   NaN       IR1          Low  ...         0     NaN  MnPrv          NaN
# 2927   NaN       Reg          Lvl  ...         0     NaN  MnPrv         Shed
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# 2       12500       6    2010       WD           Normal     172000
# 3           0       4    2010       WD           Normal     244000
# 4           0       3    2010       WD           Normal     189900
# ...       ...     ...     ...       ...             ...        ...
# 2925        0       3    2006       WD           Normal     142500
# 2926        0       6    2006       WD           Normal     131000
# 2927      700       7    2006       WD           Normal     132000
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %%
#First remove useless columns (es:Order that has incremental orders, but not much information)
#Figure out if PID is a row identifier
df["Order"].nunique() #tells me how many unique values i have in this column
df["PID"].nunique()
# Out:
# 2930

# %%
#both columns are unique identifiers...we can decide to remove one. Let's keep PID because if there were 
# other tables it could be linked to them
df.drop(columns=["Order"],inplace=True)

# %%
df
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2925  923275080           80        RL          37.0      7937   Pave   NaN
# 2926  923276100           20        RL           NaN      8885   Pave   NaN
# 2927  923400125           85        RL          62.0     10441   Pave   NaN
# 2928  924100070           20        RL          77.0     10010   Pave   NaN
# 2929  924151050           60        RL          74.0      9627   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# 0          IR1          Lvl    AllPub  ...         0     NaN    NaN
# 1          Reg          Lvl    AllPub  ...         0     NaN  MnPrv
# 2          IR1          Lvl    AllPub  ...         0     NaN    NaN
# 3          Reg          Lvl    AllPub  ...         0     NaN    NaN
# 4          IR1          Lvl    AllPub  ...         0     NaN  MnPrv
# ...        ...          ...       ...  ...       ...     ...    ...
# 2925       IR1          Lvl    AllPub  ...         0     NaN  GdPrv
# 2926       IR1          Low    AllPub  ...         0     NaN  MnPrv
# 2927       Reg          Lvl    AllPub  ...         0     NaN  MnPrv
# 2928       Reg          Lvl    AllPub  ...         0     NaN    NaN
# 2929       Reg          Lvl    AllPub  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 0             NaN        0       5    2010        WD           Normal
# 1             NaN        0       6    2010        WD           Normal
# 2            Gar2    12500       6    2010        WD           Normal
# 3             NaN        0       4    2010        WD           Normal
# 4             NaN        0       3    2010        WD           Normal
# ...           ...      ...     ...     ...        ...             ...
# 2925          NaN        0       3    2006        WD           Normal
# 2926          NaN        0       6    2006        WD           Normal
# 2927         Shed      700       7    2006        WD           Normal
# 2928          NaN        0       4    2006        WD           Normal
# 2929          NaN        0      11    2006        WD           Normal
#
#       SalePrice
# 0        215000
# 1        105000
# 2        172000
# 3        244000
# 4        189900
# ...         ...
# 2925     142500
# 2926     131000
# 2927     132000
# 2928     170000
# 2929     188000
#
# [2930 rows x 81 columns]

# %%
df.set_index("PID",inplace=True)

# %%
df
# Out:
#            MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# PID
# 526301100           20        RL         141.0     31770   Pave   NaN
# 526350040           20        RH          80.0     11622   Pave   NaN
# 526351010           20        RL          81.0     14267   Pave   NaN
# 526353030           20        RL          93.0     11160   Pave   NaN
# 527105010           60        RL          74.0     13830   Pave   NaN
# ...                ...       ...           ...       ...    ...   ...
# 923275080           80        RL          37.0      7937   Pave   NaN
# 923276100           20        RL           NaN      8885   Pave   NaN
# 923400125           85        RL          62.0     10441   Pave   NaN
# 924100070           20        RL          77.0     10010   Pave   NaN
# 924151050           60        RL          74.0      9627   Pave   NaN
#
#           Lot Shape Land Contour Utilities Lot Config  ... Pool Area Pool QC  \
# PID                                                    ...
# 526301100       IR1          Lvl    AllPub     Corner  ...         0     NaN
# 526350040       Reg          Lvl    AllPub     Inside  ...         0     NaN
# 526351010       IR1          Lvl    AllPub     Corner  ...         0     NaN
# 526353030       Reg          Lvl    AllPub     Corner  ...         0     NaN
# 527105010       IR1          Lvl    AllPub     Inside  ...         0     NaN
# ...             ...          ...       ...        ...  ...       ...     ...
# 923275080       IR1          Lvl    AllPub    CulDSac  ...         0     NaN
# 923276100       IR1          Low    AllPub     Inside  ...         0     NaN
# 923400125       Reg          Lvl    AllPub     Inside  ...         0     NaN
# 924100070       Reg          Lvl    AllPub     Inside  ...         0     NaN
# 924151050       Reg          Lvl    AllPub     Inside  ...         0     NaN
#
#            Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  \
# PID
# 526301100    NaN          NaN        0       5     2010        WD
# 526350040  MnPrv          NaN        0       6     2010        WD
# 526351010    NaN         Gar2    12500       6     2010        WD
# 526353030    NaN          NaN        0       4     2010        WD
# 527105010  MnPrv          NaN        0       3     2010        WD
# ...          ...          ...      ...     ...      ...        ...
# 923275080  GdPrv          NaN        0       3     2006        WD
# 923276100  MnPrv          NaN        0       6     2006        WD
# 923400125  MnPrv         Shed      700       7     2006        WD
# 924100070    NaN          NaN        0       4     2006        WD
# 924151050    NaN          NaN        0      11     2006        WD
#
#            Sale Condition  SalePrice
# PID
# 526301100          Normal     215000
# 526350040          Normal     105000
# 526351010          Normal     172000
# 526353030          Normal     244000
# 527105010          Normal     189900
# ...                   ...        ...
# 923275080          Normal     142500
# 923276100          Normal     131000
# 923400125          Normal     132000
# 924100070          Normal     170000
# 924151050          Normal     188000
#
# [2930 rows x 80 columns]

# %%
#figure out what kind of columns we have
for key,value in df.dtypes.items():
    print(key,value)
# Out:
# MS SubClass int64
# ,MS Zoning object
# ,Lot Frontage float64
# ,Lot Area int64
# ,Street object
# ,Alley object
# ,Lot Shape object
# ,Land Contour object
# ,Utilities object
# ,Lot Config object
# ,Land Slope object
# ,Neighborhood object
# ,Condition 1 object
# ,Condition 2 object
# ,Bldg Type object
# ,House Style object
# ,Overall Qual int64
# ,Overall Cond int64
# ,Year Built int64
# ,Year Remod/Add int64
# ,Roof Style object
# ,Roof Matl object
# ,Exterior 1st object
# ,Exterior 2nd object
# ,Mas Vnr Type object
# ,Mas Vnr Area float64
# ,Exter Qual object
# ,Exter Cond object
# ,Foundation object
# ,Bsmt Qual object
# ,Bsmt Cond object
# ,Bsmt Exposure object
# ,BsmtFin Type 1 object
# ,BsmtFin SF 1 float64
# ,BsmtFin Type 2 object
# ,BsmtFin SF 2 float64
# ,Bsmt Unf SF float64
# ,Total Bsmt SF float64
# ,Heating object
# ,Heating QC object
# ,Central Air object
# ,Electrical object
# ,1st Flr SF int64
# ,2nd Flr SF int64
# ,Low Qual Fin SF int64
# ,Gr Liv Area int64
# ,Bsmt Full Bath float64
# ,Bsmt Half Bath float64
# ,Full Bath int64
# ,Half Bath int64
# ,Bedroom AbvGr int64
# ,Kitchen AbvGr int64
# ,Kitchen Qual object
# ,TotRms AbvGrd int64
# ,Functional object
# ,Fireplaces int64
# ,Fireplace Qu object
# ,Garage Type object
# ,Garage Yr Blt float64
# ,Garage Finish object
# ,Garage Cars float64
# ,Garage Area float64
# ,Garage Qual object
# ,Garage Cond object
# ,Paved Drive object
# ,Wood Deck SF int64
# ,Open Porch SF int64
# ,Enclosed Porch int64
# ,3Ssn Porch int64
# ,Screen Porch int64
# ,Pool Area int64
# ,Pool QC object
# ,Fence object
# ,Misc Feature object
# ,Misc Val int64
# ,Mo Sold int64
# ,Yr Sold int64
# ,Sale Type object
# ,Sale Condition object
# ,SalePrice int64

# %%
#want to look at numerical data separately than categorical data
#spilt them:
df_num=df.select_dtypes([int,float])# selecte subsets of the columns based on data type
# we could also do df.select_dtypes(np.number)

# %%
df_cat=df.select_dtypes(include="object")
df_cat
# Out:
#           MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# PID
# 526301100        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 526350040        RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 526351010        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 526353030        RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 527105010        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...             ...    ...   ...       ...          ...       ...        ...
# 923275080        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 923276100        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 923400125        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 924100070        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 924151050        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#           Land Slope Neighborhood Condition 1  ... Garage Type Garage Finish  \
# PID                                            ...
# 526301100        Gtl        NAmes        Norm  ...      Attchd           Fin
# 526350040        Gtl        NAmes       Feedr  ...      Attchd           Unf
# 526351010        Gtl        NAmes        Norm  ...      Attchd           Unf
# 526353030        Gtl        NAmes        Norm  ...      Attchd           Fin
# 527105010        Gtl      Gilbert        Norm  ...      Attchd           Fin
# ...              ...          ...         ...  ...         ...           ...
# 923275080        Gtl      Mitchel        Norm  ...      Detchd           Unf
# 923276100        Mod      Mitchel        Norm  ...      Attchd           Unf
# 923400125        Gtl      Mitchel        Norm  ...         NaN           NaN
# 924100070        Mod      Mitchel        Norm  ...      Attchd           RFn
# 924151050        Mod      Mitchel        Norm  ...      Attchd           Fin
#
#           Garage Qual Garage Cond Paved Drive Pool QC  Fence Misc Feature  \
# PID
# 526301100          TA          TA           P     NaN    NaN          NaN
# 526350040          TA          TA           Y     NaN  MnPrv          NaN
# 526351010          TA          TA           Y     NaN    NaN         Gar2
# 526353030          TA          TA           Y     NaN    NaN          NaN
# 527105010          TA          TA           Y     NaN  MnPrv          NaN
# ...               ...         ...         ...     ...    ...          ...
# 923275080          TA          TA           Y     NaN  GdPrv          NaN
# 923276100          TA          TA           Y     NaN  MnPrv          NaN
# 923400125         NaN         NaN           Y     NaN  MnPrv         Shed
# 924100070          TA          TA           Y     NaN    NaN          NaN
# 924151050          TA          TA           Y     NaN    NaN          NaN
#
#           Sale Type Sale Condition
# PID
# 526301100       WD          Normal
# 526350040       WD          Normal
# 526351010       WD          Normal
# 526353030       WD          Normal
# 527105010       WD          Normal
# ...             ...            ...
# 923275080       WD          Normal
# 923276100       WD          Normal
# 923400125       WD          Normal
# 924100070       WD          Normal
# 924151050       WD          Normal
#
# [2930 rows x 43 columns]

# %%
df_num
# Out:
#            MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# PID
# 526301100           20         141.0     31770             6             5
# 526350040           20          80.0     11622             5             6
# 526351010           20          81.0     14267             6             6
# 526353030           20          93.0     11160             7             5
# 527105010           60          74.0     13830             5             5
# ...                ...           ...       ...           ...           ...
# 923275080           80          37.0      7937             6             6
# 923276100           20           NaN      8885             5             5
# 923400125           85          62.0     10441             5             5
# 924100070           20          77.0     10010             5             5
# 924151050           60          74.0      9627             7             5
#
#            Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# PID
# 526301100        1960            1960         112.0         639.0
# 526350040        1961            1961           0.0         468.0
# 526351010        1958            1958         108.0         923.0
# 526353030        1968            1968           0.0        1065.0
# 527105010        1997            1998           0.0         791.0
# ...               ...             ...           ...           ...
# 923275080        1984            1984           0.0         819.0
# 923276100        1983            1983           0.0         301.0
# 923400125        1992            1992           0.0         337.0
# 924100070        1974            1975           0.0        1071.0
# 924151050        1993            1994          94.0         758.0
#
#            BsmtFin SF 2  ...  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# PID                      ...
# 526301100           0.0  ...           210             62               0
# 526350040         144.0  ...           140              0               0
# 526351010           0.0  ...           393             36               0
# 526353030           0.0  ...             0              0               0
# 527105010           0.0  ...           212             34               0
# ...                 ...  ...           ...            ...             ...
# 923275080           0.0  ...           120              0               0
# 923276100         324.0  ...           164              0               0
# 923400125           0.0  ...            80             32               0
# 924100070         123.0  ...           240             38               0
# 924151050           0.0  ...           190             48               0
#
#            3Ssn Porch  Screen Porch  Pool Area  Misc Val  Mo Sold  Yr Sold  \
# PID
# 526301100           0             0          0         0        5     2010
# 526350040           0           120          0         0        6     2010
# 526351010           0             0          0     12500        6     2010
# 526353030           0             0          0         0        4     2010
# 527105010           0             0          0         0        3     2010
# ...               ...           ...        ...       ...      ...      ...
# 923275080           0             0          0         0        3     2006
# 923276100           0             0          0         0        6     2006
# 923400125           0             0          0       700        7     2006
# 924100070           0             0          0         0        4     2006
# 924151050           0             0          0         0       11     2006
#
#            SalePrice
# PID
# 526301100     215000
# 526350040     105000
# 526351010     172000
# 526353030     244000
# 527105010     189900
# ...              ...
# 923275080     142500
# 923276100     131000
# 923400125     132000
# 924100070     170000
# 924151050     188000
#
# [2930 rows x 37 columns]

# %%
df_num.columns #look at informations
# Out:
# Index(['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area',
#        'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area',
#        'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath',
#        'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Wood Deck SF',
#        'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch',
#        'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'SalePrice'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(figsize=(10,3))
ax.hist(df["SalePrice"],bins=50, edgecolor="k")
ax.set_xlabel("Sale price [$]")
ax.set_ylabel("Count")
ax.grid()
ax.set_axisbelow(True) #grid in background

# %%
df["SalePrice"].mean()
# Out:
# np.float64(180796.0600682594)

# %%
df["SalePrice"].mode()
# Out:
# 0    135000
# Name: SalePrice, dtype: int64

# %%
df["SalePrice"].median()
# Out:
# np.float64(160000.0)

# %%
fig,ax=plt.subplots(6,6,figsize=(15,15))
plt.tight_layout()
for i in range(6):
    for j in range(6):
        col_index=i*6+j
        col_name=df_num.columns[col_index]
        ax[i,j].set_title(col_name)
        ax[i,j].hist(df_num[col_name], bins=25, edgecolor="k")

# %%
df["Garage Yr Blt"].max() #viene un valore di anno nel futuro --> PROBLEMA!
# Out:
# np.float64(2207.0)

# %%
df["Garage Yr Blt"].sort_values().dropna()[-5:]
# Out:
# PID
# 533238045    2010.0
# 528120060    2010.0
# 916386020    2010.0
# 528175010    2010.0
# 916384070    2207.0
# Name: Garage Yr Blt, dtype: float64

# %%
df.loc[916384070]["Year Built"]
# Out:
# np.int64(2006)
